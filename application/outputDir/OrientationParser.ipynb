# %%
from math import atan2,degrees

def GetAngleOfLineBetweenTwoPoints(p1, p2):
        xDiff = p2[0] - p1[0]
        yDiff = p2[1] - p1[1]
        return degrees(atan2(yDiff, xDiff))

# %%
import os

fileNames = []

for fNames in os.listdir("."):
    if 'log' in fNames:
        fileNames.append(fNames)
                    
print fileNames
# Out:
# ['AprilTagFinder_log_01502.m', 'AprilTagFinder_log_00656.m', 'AprilTagFinder_log_01584.m', 'AprilTagFinder_log_00990.m', 'AprilTagFinder_log_00683.m', 'AprilTagFinder_log_01340.m', 'AprilTagFinder_log_00405.m', 'AprilTagFinder_log_01310.m', 'AprilTagFinder_log_00401.m', 'AprilTagFinder_log_01272.m', 'AprilTagFinder_log_00018.m', 'AprilTagFinder_log_01392.m', 'AprilTagFinder_log_00222.m', 'AprilTagFinder_log_01056.m', 'AprilTagFinder_log_00898.m', 'AprilTagFinder_log_00847.m', 'AprilTagFinder_log_00036.m', 'AprilTagFinder_log_00702.m', 'AprilTagFinder_log_01296.m', 'AprilTagFinder_log_00863.m', 'AprilTagFinder_log_01489.m', 'AprilTagFinder_log_00240.m', 'AprilTagFinder_log_00741.m', 'AprilTagFinder_log_01587.m', 'AprilTagFinder_log_00068.m', 'AprilTagFinder_log_00024.m', 'AprilTagFinder_log_00003.m', 'AprilTagFinder_log_00235.m', 'AprilTagFinder_log_01152.m', 'AprilTagFinder_log_01160.m', 'AprilTagFinder_log_01169.m', 'AprilTagFinder_log_00967.m', 'AprilTagFinder_log_01323.m', 'AprilTagFinder_log_00131.m', 'AprilTagFinder_log_01585.m', 'AprilTagFinder_log_01614.m', 'AprilTagFinder_log_00197.m', 'AprilTagFinder_log_00417.m', 'AprilTagFinder_log_00147.m', 'AprilTagFinder_log_00851.m', 'AprilTagFinder_log_01421.m', 'AprilTagFinder_log_01465.m', 'AprilTagFinder_log_00637.m', 'AprilTagFinder_log_01545.m', 'AprilTagFinder_log_01091.m', 'AprilTagFinder_log_00403.m', 'AprilTagFinder_log_01496.m', 'AprilTagFinder_log_00361.m', 'AprilTagFinder_log_00014.m', 'AprilTagFinder_log_00911.m', 'AprilTagFinder_log_00834.m', 'AprilTagFinder_log_00838.m', 'AprilTagFinder_log_00233.m', 'AprilTagFinder_log_00126.m', 'AprilTagFinder_log_01153.m', 'AprilTagFinder_log_01565.m', 'AprilTagFinder_log_01486.m', 'AprilTagFinder_log_00320.m', 'AprilTagFinder_log_00540.m', 'AprilTagFinder_log_01408.m', 'AprilTagFinder_log_00756.m', 'AprilTagFinder_log_00986.m', 'AprilTagFinder_log_01284.m', 'AprilTagFinder_log_01615.m', 'AprilTagFinder_log_00267.m', 'AprilTagFinder_log_01595.m', 'AprilTagFinder_log_01068.m', 'AprilTagFinder_log_00075.m', 'AprilTagFinder_log_00642.m', 'AprilTagFinder_log_00038.m', 'AprilTagFinder_log_00704.m', 'AprilTagFinder_log_01028.m', 'AprilTagFinder_log_01485.m', 'AprilTagFinder_log_00242.m', 'AprilTagFinder_log_01181.m', 'AprilTagFinder_log_00170.m', 'AprilTagFinder_log_00659.m', 'AprilTagFinder_log_01140.m', 'AprilTagFinder_log_00795.m', 'AprilTagFinder_log_00868.m', 'AprilTagFinder_log_00111.m', 'AprilTagFinder_log_00266.m', 'AprilTagFinder_log_00271.m', 'AprilTagFinder_log_00900.m', 'AprilTagFinder_log_00772.m', 'AprilTagFinder_log_01303.m', 'AprilTagFinder_log_01022.m', 'AprilTagFinder_log_01180.m', 'AprilTagFinder_log_01195.m', 'AprilTagFinder_log_00200.m', 'AprilTagFinder_log_00661.m', 'AprilTagFinder_log_00337.m', 'AprilTagFinder_log_01318.m', 'AprilTagFinder_log_00020.m', 'AprilTagFinder_log_00035.m', 'AprilTagFinder_log_00291.m', 'AprilTagFinder_log_00905.m', 'AprilTagFinder_log_00503.m', 'AprilTagFinder_log_00494.m', 'AprilTagFinder_log_00976.m', 'AprilTagFinder_log_01157.m', 'AprilTagFinder_log_00376.m', 'AprilTagFinder_log_00556.m', 'AprilTagFinder_log_00869.m', 'AprilTagFinder_log_01255.m', 'AprilTagFinder_log_00685.m', 'AprilTagFinder_log_01283.m', 'AprilTagFinder_log_01533.m', 'AprilTagFinder_log_00810.m', 'AprilTagFinder_log_00507.m', 'AprilTagFinder_log_00191.m', 'AprilTagFinder_log_00605.m', 'AprilTagFinder_log_01247.m', 'AprilTagFinder_log_01118.m', 'AprilTagFinder_log_00691.m', 'AprilTagFinder_log_01307.m', 'AprilTagFinder_log_01619.m', 'AprilTagFinder_log_00663.m', 'AprilTagFinder_log_01184.m', 'AprilTagFinder_log_00890.m', 'AprilTagFinder_log_01150.m', 'AprilTagFinder_log_00246.m', 'AprilTagFinder_log_01493.m', 'AprilTagFinder_log_00201.m', 'AprilTagFinder_log_00788.m', 'AprilTagFinder_log_00571.m', 'AprilTagFinder_log_00008.m', 'AprilTagFinder_log_00952.m', 'AprilTagFinder_log_00368.m', 'AprilTagFinder_log_00207.m', 'AprilTagFinder_log_00089.m', 'AprilTagFinder_log_00148.m', 'AprilTagFinder_log_00991.m', 'AprilTag ...

# %%
for f in fileNames:
    fileVal = open(f, 'r')
    dataVal = {}
    count = 0
    cxy = 0
    cxy_val = []
    for lines in fileVal:
        if 'tag.id' in lines:
            idVal = lines.split('=')[1]
            idVal = int(idVal.split(';')[0])
            dataVal[idVal] = {}
        
        if 'tag.p' in lines:
            coordinates = lines.split('=')[1]
            count = 1
            coordinates = coordinates.split(',')
            x_val = coordinates[0].split('[')
            x_val = float(x_val[1])
            y_val = coordinates[1].split(';')
            y_val = float(y_val[0])
           
            dataVal[idVal][count] = [x_val, y_val]
        
        if count == 1 and 'tag' not in lines:
            count = 0
            coordinates = lines.split(',')
            
            x_val = float(coordinates[0])
            y_val = coordinates[1].split(';')
            y_val = float(y_val[0])
            
            dataVal[idVal][2] = [x_val, y_val]
        
        if 'tag.c' in lines:
            cxy_val = []
            coordinates = lines.split('=[')
            x_val = float(coordinates[1].split(';')[0])
            cxy_val.append(x_val)
            cxy = 1
            
        if cxy == 1 and 'tag' not in lines:
            cxy = 0
            coordinates = lines.split(']')
            y_val = float(coordinates[0])
            cxy_val.append(y_val)
            dataVal[idVal][3] = cxy_val
            cxy_val = []
        
    break

# %%
for k in dataVal.keys():
    midPtx = float((dataVal[k][1][0] + dataVal[k][2][0])/2)
    midPty = float((dataVal[k][1][1] + dataVal[k][2][1])/2)
    pt1 = (midPtx, midPty)
    pt2 = (dataVal[k][3][0] , dataVal[k][3][1])
    dataVal[k]['theta'] = GetAngleOfLineBetweenTwoPoints(pt1, pt2)

# %%
for k in dataVal.keys():
    print k
    print dataVal[k]
# Out:
# 0
# {1: [930.5809055771861, 666.125584161776], 2: [936.3848374786753, 620.4000319647453], 3: [912.3756675715052, 639.8613634743352], 'theta': -170.84543976681502}
# 1
# {1: [977.1286087817191, 290.4873323467693], 2: [976.9000717116382, 268.1901889194796], 3: [960.8215307637425, 273.3969475078057], 'theta': -159.84981929355908}
# 2
# {1: [519.3487470474505, 311.9888847149979], 2: [488.0354139540576, 324.6280493893912], 3: [503.2551722951559, 331.3124357543306], 'theta': 91.92430355917891}
# 3
# {1: [573.6494595394087, 793.3164151148904], 2: [585.1448148314034, 753.3277510394064], 3: [559.8984246700787, 764.8256838236726], 'theta': -156.45524216735964}
# 4
# {1: [738.162234269529, 1027.652129350127], 2: [736.5601562724256, 1001.906142108558], 3: [718.3900333274883, 1014.684216182511], 'theta': -179.7133309988101}
# 5
# {1: [872.0599552597112, 1003.033425784239], 2: [872.774666188495, 1027.47775132518], 3: [890.29807292705, 1011.454343522336], 'theta': -12.0017527081382}
# 8
# {1: [607.856171694407, 1064.047409794208], 2: [582.9924168376588, 1048.416095017485], 3: [588.6527019842141, 1061.088924916739], 'theta': 144.34863223126828}
# 10
# {1: [575.0108781928645, 929.7217699691805], 2: [566.4492542853989, 956.5023661893896], 3: [588.6175746600815, 951.5322733526837], 'theta': 25.20782150027741}
# 11
# {1: [488.7314606180219, 875.6637702992817], 2: [466.2001260096558, 850.968020507485], 3: [470.476305789694, 871.625122931963], 'theta': 130.06959911166783}
# 13
# {1: [853.1767479197005, 1047.537728138127], 2: [836.6096622495936, 1064.666677722088], 3: [857.8555246631875, 1059.053504701009], 'theta': 12.826624661783491}
# 15
# {1: [281.6501239730138, 810.916605153129], 2: [298.8031067578924, 840.4670137116311], 3: [298.6881719254206, 823.0293764099557], 'theta': -17.466208356000397}
# 16
# {1: [516.3459112100616, 451.8469140770176], 2: [505.8097463864758, 421.2490362147444], 3: [494.6395569984745, 446.9950742202221], 'theta': 147.56260812641938}
